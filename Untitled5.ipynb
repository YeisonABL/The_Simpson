# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.offline as pyo
import plotly.graph_objs as go

# %%
df = pd.read_csv('the_simpsons')

# %%
df
# Out:
#      Season  Episode                              Title  Year Total votes  \
# 0         1        1  Simpsons Roasting on an Open Fire  1989    7,412.00
# 1         1        2                    Bart the Genius  1990    4,920.00
# 2         1        3                    Homer's Odyssey  1990    4,333.00
# 3         1        4      There's No Disgrace Like Home  1990    4,270.00
# 4         1        5                   Bart the General  1990    4,600.00
# ..      ...      ...                                ...   ...         ...
# 722      33       18           My Octopus and a Teacher  2022      302.00
# 723      33       19         Girls Just Shauna Have Fun  2022      276.00
# 724      33       20                   Marge the Meanie  2022      253.00
# 725      33       21                     Meat Is Murder  2022      274.00
# 726      33       22                     Poorhouse Rock  2022      416.00
#
#      Average rating  z-score
# 0               8.1     1.12
# ...

# %%
data_by_season = df.groupby(['Season'], as_index = False)['Average rating'].agg(['mean', 'median'])

# %%
data_by_season
# Out:
#             mean  median
# Season
# 1       7.707692    7.70
# 2       8.009091    8.00
# 3       8.154167    8.20
# 4       8.272727    8.20
# 5       8.322727    8.30
# 6       8.344000    8.50
# 7       8.360000    8.40
# 8       8.216000    8.10
# 9       7.824000    7.90
# 10      7.600000    7.60
# 11      7.290909    7.30
# 12      7.323810    7.20
# 13      7.081818    7.10
# 14      7.036364    7.05
# 15      7.000000    7.10
# 16      6.980952    7.00
# 17      6.827273    6.80
# 18      6.922727    6.90
# 19      6.880000    6.80
# 20      6.885714    7.00
# 21      6.795652    6.80
# 22      6.722727    6.75
# 23      6.740909    6.85
# 24      6.718182    6.75
# 25      6.745455    6.65
# 26      6.604545    6.60
# 27      6.627273    6.55
# 28      6.428571    6.40
# 29      6.557143    6.50
# 30      6.147826    6.20
# 31      6.409091    6.50
# 32      6.354545    6.30
# 33      6.463636    6.50

# %%
fig = px.line(data_by_season,data_by_season.index,data_by_season['mean'], title= 'Mean avegare rating by season')
pyo.plot(fig, filename='avgseason.html')
# Out:
# 'avgseason.html'

# %%
data_by_season_and_episode = df.groupby(['Season'], as_index = True)

# %%
data_by_season_and_episode.head()
# Out:
#      Season  Episode                              Title  Year Total votes  \
# 0         1        1  Simpsons Roasting on an Open Fire  1989    7,412.00
# 1         1        2                    Bart the Genius  1990    4,920.00
# 2         1        3                    Homer's Odyssey  1990    4,333.00
# 3         1        4      There's No Disgrace Like Home  1990    4,270.00
# 4         1        5                   Bart the General  1990    4,600.00
# ..      ...      ...                                ...   ...         ...
# 705      33        1          The Star of the Backstage  2021      963.00
# 706      33        2                    Bart's in Jail!  2021      606.00
# 707      33        3          Treehouse of Horror XXXII  2021      641.00
# 708      33        4                   The Wayz We Were  2021      507.00
# 709      33        5                       Lisa's Belly  2021      580.00
#
#      Average rating  z-score
# 0               8.1     1.12
# ...

# %%
season_1 = df.loc[df['Season'] == 1]
season_2 = df.loc[df['Season'] == 2]
season_3 = df.loc[df['Season'] == 3]
season_4 = df.loc[df['Season'] == 4]
season_5 = df.loc[df['Season'] == 5]
season_6 = df.loc[df['Season'] == 6]
season_7 = df.loc[df['Season'] == 7]
season_8 = df.loc[df['Season'] == 8]
season_9 = df.loc[df['Season'] == 9]
season_10 = df.loc[df['Season'] == 10]
season_11 = df.loc[df['Season'] == 11]
season_12 = df.loc[df['Season'] == 12]
season_13 = df.loc[df['Season'] == 13]
season_14 = df.loc[df['Season'] == 14]
season_15 = df.loc[df['Season'] == 15]
season_16 = df.loc[df['Season'] == 16]
season_17 = df.loc[df['Season'] == 17]
season_18 = df.loc[df['Season'] == 18]
season_19 = df.loc[df['Season'] == 19]
season_20 = df.loc[df['Season'] == 20]
season_21 = df.loc[df['Season'] == 21]
season_22 = df.loc[df['Season'] == 22]
season_23 = df.loc[df['Season'] == 23]
season_24 = df.loc[df['Season'] == 24]
season_25 = df.loc[df['Season'] == 25]
season_26 = df.loc[df['Season'] == 26]
season_27 = df.loc[df['Season'] == 27]
season_28 = df.loc[df['Season'] == 28]
season_29 = df.loc[df['Season'] == 29]
season_30 = df.loc[df['Season'] == 30]
season_31 = df.loc[df['Season'] == 31]
season_32 = df.loc[df['Season'] == 32]
season_33 = df.loc[df['Season'] == 33]

# %%
trace1 = go.Scatter(x=season_1['Episode'], y=season_1['Average rating'], mode ='lines', name ='Season 1')
trace2 = go.Scatter(x=season_2['Episode'], y=season_2['Average rating'], mode ='lines', name ='Season 2')
trace3 = go.Scatter(x=season_3['Episode'], y=season_3['Average rating'], mode ='lines', name ='Season 3')
trace4 = go.Scatter(x=season_4['Episode'], y=season_4['Average rating'], mode ='lines', name ='Season 4')
trace5 = go.Scatter(x=season_5['Episode'], y=season_5['Average rating'], mode ='lines', name ='Season 5')
trace6 = go.Scatter(x=season_6['Episode'], y=season_6['Average rating'], mode ='lines', name ='Season 6')
trace7 = go.Scatter(x=season_7['Episode'], y=season_7['Average rating'], mode ='lines', name ='Season 7')
trace8 = go.Scatter(x=season_8['Episode'], y=season_8['Average rating'], mode ='lines', name ='Season 8')
trace9 = go.Scatter(x=season_9['Episode'], y=season_9['Average rating'], mode ='lines', name ='Season 9')
trace10 = go.Scatter(x=season_10['Episode'], y=season_10['Average rating'], mode ='lines', name ='Season 10')
trace11 = go.Scatter(x=season_11['Episode'], y=season_11['Average rating'], mode ='lines', name ='Season 11')
trace12 = go.Scatter(x=season_12['Episode'], y=season_12['Average rating'], mode ='lines', name ='Season 12')
trace13 = go.Scatter(x=season_13['Episode'], y=season_13['Average rating'], mode ='lines', name ='Season 13')
trace14 = go.Scatter(x=season_14['Episode'], y=season_14['Average rating'], mode ='lines', name ='Season 14')
trace15 = go.Scatter(x=season_15['Episode'], y=season_15['Average rating'], mode ='lines', name ='Season 15')
trace16 = go.Scatter(x=season_16['Episode'], y=season_16['Average rating'], mode ='lines', name ='Season 16')
trace17 = go.Scatter(x=season_17['Episode'], y=season_17['Average rating'], mode ='lines', name ='Season 17')
trace18 = go.Scatter(x=season_18['Episode'], y=season_18['Average rating'], mode ='lines', name ='Season 18')
trace19 = go.Scatter(x=season_19['Episode'], y=season_19['Average rating'], mode ='lines', name ='Season 19')
trace20 = go.Scatter(x=season_20['Episode'], y=season_20['Average rating'], mode ='lines', name ='Season 20')
trace21 = go.Scatter(x=season_21['Episode'], y=season_21['Average rating'], mode ='lines', name ='Season 21')
trace22 = go.Scatter(x=season_22['Episode'], y=season_22['Average rating'], mode ='lines', name ='Season 22')
trace23 = go.Scatter(x=season_23['Episode'], y=season_23['Average rating'], mode ='lines', name ='Season 23')
trace24 = go.Scatter(x=season_24['Episode'], y=season_24['Average rating'], mode ='lines', name ='Season 24')
trace25 = go.Scatter(x=season_25['Episode'], y=season_25['Average rating'], mode ='lines', name ='Season 25')
trace26 = go.Scatter(x=season_26['Episode'], y=season_26['Average rating'], mode ='lines', name ='Season 26')
trace27 = go.Scatter(x=season_27['Episode'], y=season_27['Average rating'], mode ='lines', name ='Season 27')
trace28 = go.Scatter(x=season_28['Episode'], y=season_28['Average rating'], mode ='lines', name ='Season 28')
trace29 = go.Scatter(x=season_29['Episode'], y=season_29['Average rating'], mode ='lines', name ='Season 29')
trace30 = go.Scatter(x=season_30['Episode'], y=season_30['Average rating'], mode ='lines', name ='Season 30')
trace31 = go.Scatter(x=season_31['Episode'], y=season_31['Average rating'], mode ='lines', name ='Season 31')
trace32 = go.Scatter(x=season_32['Episode'], y=season_32['Average rating'], mode ='lines', name ='Season 32')
trace33 = go.Scatter(x=season_33['Episode'], y=season_33['Average rating'], mode ='lines', name ='Season 33')

# %%
data = [trace7, trace8, trace9]
#data = [trace1, trace2, trace3, trace4, trace5, trace6, trace7, trace8, trace9, trace10, trace11, trace12, trace13, trace14, trace15, trace16, trace17, trace18, trace19, trace20, trace21, trace22, trace23, trace24, trace25, trace26, trace27, trace28, trace29, trace30, trace31, trace32, trace33]

# %%
layout = go.Layout(title = 'Season')

# %%
figure = go.Figure(data=data, layout= layout)
pyo.plot(figure, filename='allseasons.html')
# Out:
# 'allseasons.html'

# %%
df.loc[df['Season'] == 1]
# Out:
#     Season  Episode                              Title  Year Total votes  \
# 0        1        1  Simpsons Roasting on an Open Fire  1989    7,412.00
# 1        1        2                    Bart the Genius  1990    4,920.00
# 2        1        3                    Homer's Odyssey  1990    4,333.00
# 3        1        4      There's No Disgrace Like Home  1990    4,270.00
# 4        1        5                   Bart the General  1990    4,600.00
# 5        1        6                       Moaning Lisa  1990    4,147.00
# 6        1        7           The Call of the Simpsons  1990    4,008.00
# 7        1        8                  The Telltale Head  1990    3,858.00
# 8        1        9              Life on the Fast Lane  1990    3,823.00
# 9        1       10                  Homer's Night Out  1990    3,706.00
# 10       1       11                The Crepes of Wrath  1990    3,767.00
# 11       1       12                 Krusty Gets Busted  1990    4,151.00
# ...

# %%
for i in range(33):
   season +_+str(i)= df.loc[df['Season'] == i]
# Out:
#   File "C:\Users\YEISON~1\AppData\Local\Temp/ipykernel_55072/3446041856.py", line 2
#     season +_+str(i)= df.loc[df['Season'] == i]
#     ^
# SyntaxError: cannot assign to operator

# %%
season_6
# Out:
#      Season  Episode                         Title  Year Total votes  \
# 103       6        1              Bart of Darkness  1994    3,274.00
# 104       6        2                  Lisa's Rival  1994    2,765.00
# 105       6        3    Another Simpsons Clip Show  1994    2,439.00
# 106       6        4         Itchy & Scratchy Land  1994    3,108.00
# 107       6        5          Sideshow Bob Roberts  1994    2,725.00
# 108       6        6         Treehouse of Horror V  1994    4,335.00
# 109       6        7             Bart's Girlfriend  1994    2,716.00
# 110       6        8                   Lisa on Ice  1994    2,972.00
# 111       6        9                  Homer Badman  1994    4,100.00
# 112       6       10  Grampa vs. Sexual Inadequacy  1994    2,534.00
# 113       6       11                Fear of Flying  1994    2,582.00
# 114       6       12               Homer the Great  1995    3,801.00
# 115       6       13        And Maggie Makes Three  1995    3,331.00
# ...

# %%
season_9
# Out:
#      Season  Episode                                   Title  Year  \
# 178       9        1  The City of New York vs. Homer Simpson  1997
# 179       9        2            The Principal and the Pauper  1997
# 180       9        3                              Lisa's Sax  1997
# 181       9        4                Treehouse of Horror VIII  1997
# 182       9        5                    The Cartridge Family  1997
# 183       9        6                               Bart Star  1997
# 184       9        7        The Two Mrs. Nahasapeemapetilons  1997
# 185       9        8                        Lisa the Skeptic  1997
# 186       9        9                            Realty Bites  1997
# 187       9       10            Miracle on Evergreen Terrace  1997
# 188       9       11                All Singing, All Dancing  1998
# 189       9       12                              Bart Carny  1998
# 190       9       13                         The Joy of Sect  1998
# ...

# %%
season_8
# Out:
#      Season  Episode                                              Title  Year  \
# 153       8        1                            Treehouse of Horror VII  1996
# 154       8        2                                You Only Move Twice  1996
# 155       8        3                                The Homer They Fall  1996
# 156       8        4                                  Burns, Baby Burns  1996
# 157       8        5                                    Bart After Dark  1996
# 158       8        6                                 A Milhouse Divided  1996
# 159       8        7                           Lisa's Date with Density  1996
# 160       8        8                                    Hurricane Neddy  1996
# 161       8        9               El Viaje Misterioso de Nuestro Jomer  1997
# 162       8       10                              The Springfield Files  1997
# 163       8       11                 The Twisted World of Marge Simpson  1997
# ...

# %%
git remote add origin https://github.com/YeisonABL/The_Simpson.git
# Out:
#   File "C:\Users\YEISON~1\AppData\Local\Temp/ipykernel_55072/3116007240.py", line 1
#     git remote add origin https://github.com/YeisonABL/The_Simpson.git
#         ^
# SyntaxError: invalid syntax
